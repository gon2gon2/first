# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import warnings
warnings.filterwarnings('ignore')
import glob
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from lightgbm import LGBMClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder
import random
import os
from sklearn.metrics import log_loss
from bayes_opt import BayesianOptimization
import lightgbm


d = "C:\kaggle_data\credit_card"
lst = os.listdir(d)
print(lst)
train = pd.read_csv(d + '\\' +lst[3])
test = pd.read_csv(d + '\\' +lst[2])
ss = pd.read_csv(d + '\\' +lst[1])
train = train.drop(['index'], axis=1)
train.fillna('NAN', inplace=True) 
test = test.drop(['index'], axis=1)
test.fillna('NAN', inplace=True)

# Married, Civil marriage
train['income_per_size'] = np.log(train['income_total']/train['family_size'])
test['income_per_size'] = np.log(test['income_total']/test['family_size'])
train.loc[(train['family_type']=='Married')|(train['family_type']=='Civil marriage'),'income_per_size']\
= train['income_per_size'] * 2

test.loc[(test['family_type']=='Married')|(test['family_type']=='Civil marriage'),'income_per_size']\
= test['income_per_size'] * 2

def simple_marry(x):
    if x == 'Married' or x =='Civil marriage':
        return '0'
    elif x == 'Separated' or x == 'Widow':
        return '1'
    else:
        return '2'

for df in [train,test]:
    df['family_bins'] = df['family_type'].apply(simple_marry)

# income_total을 로그변환
train['income_total'] = np.log(train['income_total'])
# train = train.drop('income_total',1)
test['income_total'] = np.log(test['income_total'])
# test = test.drop('income_total',1)

# car와 reality를 합친 새로운 칼럼 careality
train['car'] =train['car'].apply(lambda x: int(x=='Y'))
train['reality'] =train['reality'].apply(lambda x: int(x=='Y'))
test['car'] =test['car'].apply(lambda x: int(x=='Y'))
test['reality'] =test['reality'].apply(lambda x: int(x=='Y'))

train['careality'] = train['car'] + train['reality']
train = train.drop(['car', 'reality'],1)

test['careality'] = test['car'] + test['reality']
test = test.drop(['car', 'reality'],1)

train.drop('gender',1,inplace=True)
test.drop('gender',1,inplace=True)

object_col = []
for col in train.columns:
    if train[col].dtype == 'object':
        object_col.append(col)

# enc = OneHotEncoder()
# enc.fit(train.loc[:,object_col])


# train_onehot_df = pd.DataFrame(enc.transform(train.loc[:,object_col]).toarray(), 
#              columns=enc.get_feature_names(object_col))
# train.drop(object_col, axis=1, inplace=True)
# train = pd.concat([train, train_onehot_df], axis=1)

# test_onehot_df = pd.DataFrame(enc.transform(test.loc[:,object_col]).toarray(), 
#              columns=enc.get_feature_names(object_col))
# test.drop(object_col, axis=1, inplace=True)
# test = pd.concat([test, test_onehot_df], axis=1)

#############################################################
enc = LabelEncoder()
# enc.fit(train.loc[:,object_col])
total = pd.concat([train, test])

for col in object_col:
    enc.fit(total[col])
    train[col] = enc.transform(train[col])
    test[col] = enc.transform(test[col])

# train_onehot_df = pd.DataFrame(enc.transform(train.loc[:,object_col]).toarray(), 
#              columns=enc.get_feature_names(object_col))
# train.drop(object_col, axis=1, inplace=True)
# train = pd.concat([train, train_onehot_df], axis=1)

# test_onehot_df = pd.DataFrame(enc.transform(test.loc[:,object_col]).toarray(), 
#              columns=enc.get_feature_names(object_col))
# test.drop(object_col, axis=1, inplace=True)
# test = pd.concat([test, test_onehot_df], axis=1)
#############################################################




## 제곱
for df in [train,test]:
    df['income_per_size'] = df['income_per_size'].apply(lambda x: x**2)
    
c = 'income_per_size'
mean = train[c].mean()
std = train[c].std()

# 기존 
train[c] = (train[c]-mean)/std
test[c] = (test[c]-mean)/std

#####################
c = 'income_total'
k = 2.2
mean = train[c].mean()
std = train[c].std()
idxs = train.loc[(train[c]>= mean + k*std)|\
                (train[c]<= mean - k*std)].index
train = train.drop(idxs).reset_index(drop=True)

# 기존 
train[c] = (train[c]-mean)/std
test[c] = (test[c]-mean)/std

#####################
c = 'begin_month'
k = 2.2

train[c] = train[c].apply(lambda x: x**2)
test[c] = test[c].apply(lambda x: x**2)

mean = train[c].mean()
std = train[c].std()

idxs = train.loc[(train[c]>= mean + k*std)|\
                (train[c]<= mean - k*std)].index
# train = train.drop(idxs).reset_index(drop=True)

# 기존 
train[c] = (train[c]-mean)/std
test[c] = (test[c]-mean)/std

######################
c = 'DAYS_BIRTH'
k = 2.2
mean = train[c].mean()
std = train[c].std()
idxs = train.loc[(train[c]>= mean + k*std)|\
                (train[c]<= mean - k*std)].index
train = train.drop(idxs).reset_index(drop=True)

#기존 
train[c] = (train[c]-mean)/std
test[c] = (test[c]-mean)/std



###################
c = 'DAYS_EMPLOYED'
k = 2.2
mean = train[c].mean()
std = train[c].std()
idxs = train.loc[(train[c]>= mean + k*std)|\
                (train[c]<= mean - k*std)].index
train = train.drop(idxs).reset_index(drop=True)
# Out:
# ['.ipynb_checkpoints', 'sample_submission.csv', 'test.csv', 'train.csv', 'Untitled.ipynb']

# %%
train.loc[:,object_col]
# Out:
#        income_type  edu_type  family_type  house_type  occyp_type  family_bins
# 0                0         1            1           2          12            0
# 1                0         4            0           1           8            0
# 2                4         1            1           1          10            0
# 3                0         4            1           1          15            0
# 4                2         1            1           1          10            0
# ...            ...       ...          ...         ...         ...          ...
# 21504            2         4            1           1           3            0
# 21505            4         1            2           1          12            1
# 21506            4         4            0           5           3            0
# 21507            4         2            3           1           8            2
# 21508            4         4            0           1          17            0
#
# [21509 rows x 6 columns]

# %%
lightgbm.LGBMModel(params=params, )
# Out:
# ['Booster',
#  'CVBooster',
#  'Dataset',
#  'LGBMClassifier',
#  'LGBMModel',
#  'LGBMRanker',
#  'LGBMRegressor',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'absolute_import',
#  'basic',
#  'callback',
#  'compat',
#  'create_tree_digraph',
#  'cv',
#  'dir_path',
#  'early_stopping',
#  'engine',
#  'libpath',
#  'os',
#  'plot_importance',
#  'plot_metric',
#  'plot_split_value_histogram',
#  'plot_tree',
#  'plotting',
#  'print_evaluation',
#  'record_evaluation',
#  'reset_parameter',
#  'sklearn',
#  'train',
#  'version_file']

# %%
train.loc[:,object_col]
# Out:
#                 income_type                       edu_type  \
# 0      Commercial associate               Higher education
# 1      Commercial associate  Secondary / secondary special
# 2                   Working               Higher education
# 3      Commercial associate  Secondary / secondary special
# 4             State servant               Higher education
# ...                     ...                            ...
# 21504         State servant  Secondary / secondary special
# 21505               Working               Higher education
# 21506               Working  Secondary / secondary special
# 21507               Working              Incomplete higher
# 21508               Working  Secondary / secondary special
#
#                 family_type           house_type      occyp_type family_bins
# 0                   Married  Municipal apartment             NAN           0
# 1            Civil marriage    House / apartment        Laborers           0
# 2                   Married    House / apartment        Managers           0
# 3                   Married    House / apartment     Sales staff           0
# 4                   Married    House / apartment        Managers           0
# ...                     ...                  ...             ...         ...
# 21504               Married    House / apartment      Core staff           0
# 21505             Separated    House / apartment             NAN           1
# 21506        Civil marriage         With parents      Core staff           0
# 21507  Single / not married    House / apartment        Laborers           2
# 21508        Civil marriage    House / apartment  Security staff           0
#
# [21509 rows x 6 columns]

# %%
def lgb_rf(n_estimators, learning_rate,
             max_depth,
            num_leaves,
           bagging_fraction, bagging_freq,
             feature_fraction, 
             reg_lambda, reg_alpha):

    params = {
        'objective': 'multiclass',
        "metric" : "multi_logloss", 
        "num_classes" : 3,
        'boosting_type': 'rf', #########
        
        'n_estimators': int(n_estimators),  #####
        'learning_rate': learning_rate,
        'max_depth': int(max_depth),
#         'min_data_in_leaf': int(min_data_in_leaf),
        'num_leaves': int(num_leaves),
        'bagging_fraction': bagging_fraction,    ### baggin_fraction
        'bagging_freq': int(bagging_freq),
        'feature_fraction': feature_fraction, #########feature_freaction
        'reg_lambda': reg_lambda,
        'reg_alpha': reg_alpha,
        "verbosity" : -1,
        'random_state':1123
        
    }
    
    lgtrain = lightgbm.Dataset(train.drop('credit',1), train['credit'])
    cv_result = lightgbm.cv(params,
                       lgtrain,
                       1000,
                       early_stopping_rounds=100,
                       stratified=True,
                       nfold=10,
                        metrics='multi_logloss',
                        categorical_feature=object_col
                           )
    
    return -cv_result['multi_logloss-mean'][-1]

# %%
lgbBO = BayesianOptimization(lgb_rf, {
    'n_estimators': (300,20000),
    "learning_rate" : (0.001,0.05),
#     'min_data_in_leaf':(10,50),
    "max_depth" : (7,20),
    "num_leaves" : (1,100),
#     'boosting': ,
    'bagging_fraction': (0.5,1),
    'bagging_freq': (1,10), 
    'feature_fraction': (0.5,1),
    'reg_lambda':(0,1),
    'reg_alpha': (0,1),
})

lgbBO.maximize(n_iter=30, init_points=2)
# Out:
# |   iter    |  target   | featur... | learni... | max_depth | n_esti... | num_le... | reg_alpha | reg_la... |
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------
# KeyError                                Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\bayes_opt\target_space.py in probe(self, params)
#     190         try:
# --> 191             target = self._cache[_hashable(x)]
#     192         except KeyError:
#
# KeyError: (0.7783543036727991, 0.04481672836511388, 7.787051690973223, 3095.569147311198, 22.354018674795018, 0.43945026524387754, 0.34326753479853145)
#
# During handling of the above exception, another exception occurred:
#
# LightGBMError                           Traceback (most recent call last)
# <timed exec> in <module>
#
# C:\Anaconda3\lib\site-packages\bayes_opt\bayesian_optimization.py in maximize(self, init_points, n_iter, acq, kappa, kappa_decay, kappa_decay_delay, xi, **gp_params)
#     183                 iteration += 1
#     184
# --> 185             self.probe(x_probe, lazy=False)
#     186
#     187             if self._bounds_transformer:
#
# C:\Anaconda3\lib\site-packages\bayes_opt\bayesian_optimization.py in probe(self, params, lazy)
#     114             self._queue.add(params)
#     115         else:
# --> 116             self._space.probe(params)
#     117             self.dispatch(Events.OPTIMIZATION_STEP)
#     118
#
# C:\Anaconda3\lib\site-packages\bayes_opt\target_space.py in probe(self, params)
#     192         except KeyError:
#     193             params = dict(zip(self._keys, x))
# --> 194             target = self.target_func(**params)
#     195             self.register(x, target)
#     196         return target
#
# <ipython-input-46-2a3434da8a2c> in lgb_rf(n_estimators, learning_rate, max_depth, num_leaves, feature_fraction, reg_lambda, reg_alpha)
#      34                        nfold=10,
#      35                         metrics='multi_logloss',
# ---> 36                         categorical_feature=object_col
#      37                            )
#      38
#
# C:\Anaconda3\lib\site-packages\lightgbm\engine.py in cv(params, train_set, num_boost_round, folds, nfold, stratified, shuffle, metrics, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, fpreproc, verbose_eval, show_stdv, seed, callbacks, eval_train_metric, return_cvbooster)
#     561
#     562     # setup callbacks
# --> 563     if callbacks is None:
#     564         callbacks = set()
#     565     else:
#
# C:\Anaconda3\lib\site-packages\lightgbm\engine.py in _make_n_folds(full_data, folds, nfold, params, seed, fpreproc, stratified, shuffle, eval_train_metric)
#     368         if eval_train_metric:
#     369             cvbooster.add_valid(train_set, 'train')
# --> 370         cvbooster.add_valid(valid_set, 'valid')
#     371         ret._append(cvbooster)
#     372     return ret
#
# C:\Anaconda3\lib\site-packages\lightgbm\basic.py in __init__(self, params, train_set, model_file, model_str, silent)
#    1989         Returns
#    1990         -------
# -> 1991         number_of_rows : int
#    1992             The number of rows in the Dataset.
#    1993         """
#
# C:\Anaconda3\lib\site-packages\lightgbm\basic.py in _safe_call(ret)
#      53         if msg.strip() == '':
#      54             msg = ''.join(msg_normalized)
# ---> 55             msg_normalized = []
#      56             return func(msg)
#      57         else:
#
# LightGBMError: Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at d:\a\1\s\python-package\compile\src\boosting\rf.hpp, line 35 .

# %%
def lgb_gbdt(n_estimators, learning_rate,
             min_data_in_leaf, max_depth,
            num_leaves, boosting, subsample,
             feature_fraction, 
             reg_lambda, reg_alpha):

    params = {
        'objective': 'multiclass',
        "metric" : "multi_logloss", 
        "num_classes" : 3,
        'boosting': 'gbdt'
        
        'n_estimators': int(n_estimators),  #####
        'learning_rate': learning_rate,
        'max_depth': int(max_depth),
#         'min_data_in_leaf': int(min_data_in_leaf),
        'num_leaves': int(num_leaves),
        'boosting_type': boosting, #####
        'subsample': subsample,    ### baggin_fraction
        'feature_fraction': feature_fraction, #########feature_freaction
        'reg_lambda': reg_lambda,
        'reg_alpha': reg_alpha,
        'random_state':1123
        
    }
    
    lgtrain = lightgbm.Dataset(train.drop('credit',1), train['credit'])
    cv_result = lightgbm.cv(params,
                       lgtrain,
                       1000,
                       early_stopping_rounds=100,
                       stratified=True,
                       nfold=10,
                        metrics='multi_logloss',
                        categorical_feature=object_col
                           )
    
    return -cv_result['multi_logloss-mean'][-1]

# %% [markdown]
# #

# %%
| -0.7233   |  0.1537   |  0.6795   |  1.973    |  0.6301   |  0.04308  |  8.466    |  2.996    |  34.99    |  5.63     |  1.513e+0 |  67.51    |  4.752e+0 |
| -0.7191  |  0.6999   |  0.4103   |  0.6126   |  1.751    |  0.03903  |  7.725    |  16.72    |  33.04    |  0.5767   |  1.869e+0 |  96.25    |  1.079e+0 |
| -0.7209   |  0.2351   |  0.683    |  1.464    |  0.9872   |  0.01561  |  7.768    |  19.68    |  23.74    |  4.816    |  6.247e+0 |  27.23    |  2.61e+04 |
| -0.7249   |  0.004964 |  0.9696   |  0.06411  |  0.4264   |  0.0436   |  8.904    |  17.52    |  34.46    |  1.668    |  1.469e+0 |  36.89    |  2.934e+0 |
| -0.7251   |  0.1298   |  0.8323   |  1.419    |  0.648    |  0.03255  |  8.159    |  4.377    |  46.07    |  3.498    |  5.734e+0 |  63.19    |  2.603e+0 |

# %% [markdown]
# # #######모델링, 학습 시작#######
#
# |365243?|학습|예측|
# |----|----|----|
# |yes|out_train|out_test|
# |no|in_train|in_test|

# %%
n = 10

# %%
random.seed(42)
skf = StratifiedKFold(n_splits=n, shuffle=True, random_state=42)

# %% [markdown]
# ### out_train

# %%
def tr(train):
    skf = StratifiedKFold(n_splits=n, shuffle=True, random_state=42)
    folds=[]
    losses=[]
    for train_idx, valid_idx in skf.split(train, train['credit']):
        folds.append((train_idx, valid_idx))



    lgb_models={}
    for fold in range(n):
        train_idx, valid_idx = folds[fold]
        X_train, X_valid, y_train, y_valid = train.drop(['credit'],axis=1).iloc[train_idx].values, train.drop(['credit'],axis=1).iloc[valid_idx].values,\
                                             train['credit'][train_idx].values, train['credit'][valid_idx].values 
    
        
        lgb = LGBMClassifier(lambda_l1=0.014630436883633463,
      lambda_l2= 0.04929901721885113,
      learning_rate= 0.19809719345888235,
      max_depth= 43,
      min_child_samples= 8938,
      min_data_in_leaf= 105,
      n_estimators= 818,
      num_leaves= 3959)
        lgb.fit(X_train, y_train, 
                eval_set=[(X_train, y_train), (X_valid, y_valid)], 
                early_stopping_rounds=30,
               verbose=100)
        lgb_models[fold]=lgb



        losses.append(log_loss(y_valid, lgb.predict_proba(X_valid)))
    print(sum(losses)/n)
    return lgb_models

# %%
out_models = tr(out_train)
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=105, min_child_samples=8938 will be ignored. Current value: min_data_in_leaf=105
# [LightGBM] [Warning] lambda_l1 is set=0.014630436883633463, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.014630436883633463
# [LightGBM] [Warning] lambda_l2 is set=0.04929901721885113, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04929901721885113
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [46]	training's multi_logloss: 0.552073	valid_1's multi_logloss: 0.703662
# [LightGBM] [Warning] min_data_in_leaf is set=105, min_child_samples=8938 will be ignored. Current value: min_data_in_leaf=105
# [LightGBM] [Warning] lambda_l1 is set=0.014630436883633463, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.014630436883633463
# [LightGBM] [Warning] lambda_l2 is set=0.04929901721885113, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04929901721885113
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [43]	training's multi_logloss: 0.554716	valid_1's multi_logloss: 0.759542
# [LightGBM] [Warning] min_data_in_leaf is set=105, min_child_samples=8938 will be ignored. Current value: min_data_in_leaf=105
# [LightGBM] [Warning] lambda_l1 is set=0.014630436883633463, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.014630436883633463
# [LightGBM] [Warning] lambda_l2 is set=0.04929901721885113, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04929901721885113
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [54]	training's multi_logloss: 0.52068	valid_1's multi_logloss: 0.79728
# [LightGBM] [Warning] min_data_in_leaf is set=105, min_child_samples=8938 will be ignored. Current value: min_data_in_leaf=105
# [LightGBM] [Warning] lambda_l1 is set=0.014630436883633463, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.014630436883633463
# [LightGBM] [Warning] lambda_l2 is set=0.04929901721885113, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04929901721885113
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [36]	training's multi_logloss: 0.578966	valid_1's multi_logloss: 0.762783
# [LightGBM] [Warning] min_data_in_leaf is set=105, min_child_samples=8938 will be ignored. Current value: min_data_in_leaf=105
# [LightGBM] [Warning] lambda_l1 is set=0.014630436883633463, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.014630436883633463
# [LightGBM] [Warning] lambda_l2 is set=0.04929901721885113, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04929901721885113
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [59]	training's multi_logloss: 0.512335	valid_1's multi_logloss: 0.737564
# [LightGBM] [Warning] min_data_in_leaf is set=105, min_child_samples=8938 will be ignored. Current value: min_data_in_leaf=105
# [LightGBM] [Warning] lambda_l1 is set=0.014630436883633463, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.014630436883633463
# [LightGBM] [Warning] lambda_l2 is set=0.04929901721885113, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04929901721885113
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [58]	training's multi_logloss: 0.516982	valid_1's multi_logloss: 0.751308
# [LightGBM] [Warning] min_data_in_leaf is set=105, min_child_samples=8938 will be ignored. Current value: min_data_in_leaf=105
# [LightGBM] [Warning] lambda_l1 is set=0.014630436883633463, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.014630436883633463
# [LightGBM] [Warning] lambda_l2 is set=0.04929901721885113, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04929901721885113
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [19]	training's multi_logloss: 0.657353	valid_1's multi_logloss: 0.753431
# [LightGBM] [Warning] min_data_in_leaf is set=105, min_child_samples=8938 will be ignored. Current value: min_data_in_leaf=105
# [LightGBM] [Warning] lambda_l1 is set=0.014630436883633463, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.014630436883633463
# [LightGBM] [Warning] lambda_l2 is set=0.04929901721885113, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04929901721885113
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [39]	training's multi_logloss: 0.569098	valid_1's multi_logloss: 0.760431
# [LightGBM] [Warning] min_data_in_leaf is set=105, min_child_samples=8938 will be ignored. Current value: min_data_in_leaf=105
# [LightGBM] [Warning] lambda_l1 is set=0.014630436883633463, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.014630436883633463
# [LightGBM] [Warning] lambda_l2 is set=0.04929901721885113, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04929901721885113
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [60]	training's multi_logloss: 0.512134	valid_1's multi_logloss: 0.740199
# [LightGBM] [Warning] min_data_in_leaf is set=105, min_child_samples=8938 will be ignored. Current value: min_data_in_leaf=105
# [LightGBM] [Warning] lambda_l1 is set=0.014630436883633463, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.014630436883633463
# [LightGBM] [Warning] lambda_l2 is set=0.04929901721885113, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04929901721885113
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [67]	training's multi_logloss: 0.492876	valid_1's multi_logloss: 0.760319
# 0.7526519344981382

# %%
def tr(train):
    skf = StratifiedKFold(n_splits=n, shuffle=True, random_state=42)
    folds=[]
    losses=[]
    for train_idx, valid_idx in skf.split(train, train['credit']):
        folds.append((train_idx, valid_idx))



    lgb_models={}
    for fold in range(n):
        train_idx, valid_idx = folds[fold]
        X_train, X_valid, y_train, y_valid = train.drop(['credit'],axis=1).iloc[train_idx].values, train.drop(['credit'],axis=1).iloc[valid_idx].values,\
                                             train['credit'][train_idx].values, train['credit'][valid_idx].values 
    
        
        lgb = LGBMClassifier(lambda_l1= 0.04619401127783732,
  lambda_l2= 0.023516340914865916,
  learning_rate= 0.21142050117535985,
  max_depth= 9.817818031569452,
  min_child_samples= 1069.5789469296615,
  min_data_in_leaf= 159.20038594955219,
  n_estimators= 1440.4418354272257,
  num_leaves= 3976.0290566566396)
        lgb.fit(X_train, y_train, 
                eval_set=[(X_train, y_train), (X_valid, y_valid)], 
                early_stopping_rounds=30,
               verbose=100)
        lgb_models[fold]=lgb



        losses.append(log_loss(y_valid, lgb.predict_proba(X_valid)))
    print(sum(losses)/n)
    return lgb_models

# %%
in_models = tr(in_train)
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=105, min_child_samples=8938 will be ignored. Current value: min_data_in_leaf=105
# [LightGBM] [Warning] lambda_l1 is set=0.014630436883633463, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.014630436883633463
# [LightGBM] [Warning] lambda_l2 is set=0.04929901721885113, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04929901721885113
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [41]	training's multi_logloss: 0.466691	valid_1's multi_logloss: 0.727088
# [LightGBM] [Warning] min_data_in_leaf is set=105, min_child_samples=8938 will be ignored. Current value: min_data_in_leaf=105
# [LightGBM] [Warning] lambda_l1 is set=0.014630436883633463, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.014630436883633463
# [LightGBM] [Warning] lambda_l2 is set=0.04929901721885113, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04929901721885113
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [46]	training's multi_logloss: 0.450696	valid_1's multi_logloss: 0.721642
# [LightGBM] [Warning] min_data_in_leaf is set=105, min_child_samples=8938 will be ignored. Current value: min_data_in_leaf=105
# [LightGBM] [Warning] lambda_l1 is set=0.014630436883633463, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.014630436883633463
# [LightGBM] [Warning] lambda_l2 is set=0.04929901721885113, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04929901721885113
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [42]	training's multi_logloss: 0.463337	valid_1's multi_logloss: 0.742422
# [LightGBM] [Warning] min_data_in_leaf is set=105, min_child_samples=8938 will be ignored. Current value: min_data_in_leaf=105
# [LightGBM] [Warning] lambda_l1 is set=0.014630436883633463, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.014630436883633463
# [LightGBM] [Warning] lambda_l2 is set=0.04929901721885113, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04929901721885113
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [38]	training's multi_logloss: 0.483567	valid_1's multi_logloss: 0.716677
# [LightGBM] [Warning] min_data_in_leaf is set=105, min_child_samples=8938 will be ignored. Current value: min_data_in_leaf=105
# [LightGBM] [Warning] lambda_l1 is set=0.014630436883633463, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.014630436883633463
# [LightGBM] [Warning] lambda_l2 is set=0.04929901721885113, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04929901721885113
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [45]	training's multi_logloss: 0.452385	valid_1's multi_logloss: 0.719332
# [LightGBM] [Warning] min_data_in_leaf is set=105, min_child_samples=8938 will be ignored. Current value: min_data_in_leaf=105
# [LightGBM] [Warning] lambda_l1 is set=0.014630436883633463, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.014630436883633463
# [LightGBM] [Warning] lambda_l2 is set=0.04929901721885113, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04929901721885113
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [37]	training's multi_logloss: 0.48659	valid_1's multi_logloss: 0.737945
# [LightGBM] [Warning] min_data_in_leaf is set=105, min_child_samples=8938 will be ignored. Current value: min_data_in_leaf=105
# [LightGBM] [Warning] lambda_l1 is set=0.014630436883633463, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.014630436883633463
# [LightGBM] [Warning] lambda_l2 is set=0.04929901721885113, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04929901721885113
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [45]	training's multi_logloss: 0.452183	valid_1's multi_logloss: 0.716852
# [LightGBM] [Warning] min_data_in_leaf is set=105, min_child_samples=8938 will be ignored. Current value: min_data_in_leaf=105
# [LightGBM] [Warning] lambda_l1 is set=0.014630436883633463, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.014630436883633463
# [LightGBM] [Warning] lambda_l2 is set=0.04929901721885113, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04929901721885113
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [45]	training's multi_logloss: 0.452425	valid_1's multi_logloss: 0.732606
# [LightGBM] [Warning] min_data_in_leaf is set=105, min_child_samples=8938 will be ignored. Current value: min_data_in_leaf=105
# [LightGBM] [Warning] lambda_l1 is set=0.014630436883633463, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.014630436883633463
# [LightGBM] [Warning] lambda_l2 is set=0.04929901721885113, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04929901721885113
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [40]	training's multi_logloss: 0.473286	valid_1's multi_logloss: 0.733393
# [LightGBM] [Warning] min_data_in_leaf is set=105, min_child_samples=8938 will be ignored. Current value: min_data_in_leaf=105
# [LightGBM] [Warning] lambda_l1 is set=0.014630436883633463, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.014630436883633463
# [LightGBM] [Warning] lambda_l2 is set=0.04929901721885113, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04929901721885113
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [48]	training's multi_logloss: 0.439941	valid_1's multi_logloss: 0.722784
# 0.7270740868657428

# %% [markdown]
# # #######모델링, 학습 끝#######

# %%
in_zeros = np.zeros([len(in_test),3])
for fold in range(n):
    in_zeros += in_models[fold].predict_proba(in_test)/n
in_output = pd.DataFrame(in_zeros)
in_output = in_output.reindex(index=pd.Index(idx_in_test))

out_zeros = np.zeros([len(out_test),3])
for fold in range(n):
    out_zeros += out_models[fold].predict_proba(out_test)/n
out_output = pd.DataFrame(out_zeros)
out_output = out_output.reindex(index=pd.Index(idx_out_test))

in2 = np.concatenate((in_zeros,np.array(idx_in_test).reshape(-1,1)),axis=1)
out2 = np.concatenate((out_zeros,np.array(idx_out_test).reshape(-1,1)),axis=1)

output = pd.DataFrame(np.concatenate((in2,out2),axis=0),columns=[0,1,2,'index'])
output['index'] = output['index'].astype('int')

for i in range(len(output)):
    row = output.loc[output['index']==i]
    ss.iloc[i,1:] = row.iloc[:,:3]

# %%
ss.to_csv('bayesian_lgbm.csv', index=False)
