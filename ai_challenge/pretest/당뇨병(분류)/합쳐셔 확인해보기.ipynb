# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('C:/kaggle/ai_challenge/pretest/당뇨병(분류)/data/train.csv')
test = pd.read_csv('C:/kaggle/ai_challenge/pretest/당뇨병(분류)/data/test_data.csv')

# %%
train.head()
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0 -0.294118  0.487437  0.180328 -0.292929  0.000000  0.001490
# 1           1 -0.882353 -0.145729  0.081967 -0.414141  0.000000 -0.207153
# 2           2 -0.058824  0.839196  0.049180  0.000000  0.000000 -0.305514
# 3           3 -0.882353 -0.105528  0.081967 -0.535354 -0.777778 -0.162444
# 4           4  0.000000  0.376884 -0.344262 -0.292929 -0.602837  0.284650
#
#           6         7    8
# 0 -0.531170 -0.033333  0.0
# 1 -0.766866 -0.666667  1.0
# 2 -0.492741 -0.633333  0.0
# 3 -0.923997  0.000000  1.0
# 4  0.887276 -0.600000  0.0

# %%
test.head()
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0 -0.882353  0.085427 -0.016393 -0.070707 -0.579196  0.058122
# 1           1 -0.411765 -0.025126  0.245902 -0.454545  0.000000  0.061103
# 2           2 -0.529412 -0.165829  0.409836 -0.616162  0.000000 -0.126677
# 3           3 -0.882353  0.145729  0.081967 -0.272727 -0.527187  0.135618
# 4           4 -0.882353  0.497487  0.114754 -0.414141 -0.699764 -0.126677
#
#           6         7
# 0 -0.712212 -0.900000
# 1 -0.743809  0.033333
# 2 -0.795901 -0.566667
# 3 -0.819812  0.000000
# 4 -0.768574 -0.300000

# %%
train = train.drop('Unnamed: 0',axis=1)
test = test.drop('Unnamed: 0',axis=1)
# train.drop('Unnamed: 0',axis=1)

# %%
train.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.294118  0.487437  0.180328 -0.292929  0.000000  0.001490 -0.531170
# 1 -0.882353 -0.145729  0.081967 -0.414141  0.000000 -0.207153 -0.766866
# 2 -0.058824  0.839196  0.049180  0.000000  0.000000 -0.305514 -0.492741
# 3 -0.882353 -0.105528  0.081967 -0.535354 -0.777778 -0.162444 -0.923997
# 4  0.000000  0.376884 -0.344262 -0.292929 -0.602837  0.284650  0.887276
#
#           7    8
# 0 -0.033333  0.0
# 1 -0.666667  1.0
# 2 -0.633333  0.0
# 3  0.000000  1.0
# 4 -0.600000  0.0

# %%
y = train.pop('8')

# %%
train.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.294118  0.487437  0.180328 -0.292929  0.000000  0.001490 -0.531170
# 1 -0.882353 -0.145729  0.081967 -0.414141  0.000000 -0.207153 -0.766866
# 2 -0.058824  0.839196  0.049180  0.000000  0.000000 -0.305514 -0.492741
# 3 -0.882353 -0.105528  0.081967 -0.535354 -0.777778 -0.162444 -0.923997
# 4  0.000000  0.376884 -0.344262 -0.292929 -0.602837  0.284650  0.887276
#
#           7
# 0 -0.033333
# 1 -0.666667
# 2 -0.633333
# 3  0.000000
# 4 -0.600000

# %%
hap = pd.concat([train,test])

# %%
hap
# Out:
#            0         1         2         3         4         5         6  \
# 0  -0.294118  0.487437  0.180328 -0.292929  0.000000  0.001490 -0.531170
# 1  -0.882353 -0.145729  0.081967 -0.414141  0.000000 -0.207153 -0.766866
# 2  -0.058824  0.839196  0.049180  0.000000  0.000000 -0.305514 -0.492741
# 3  -0.882353 -0.105528  0.081967 -0.535354 -0.777778 -0.162444 -0.923997
# 4   0.000000  0.376884 -0.344262 -0.292929 -0.602837  0.284650  0.887276
# ..       ...       ...       ...       ...       ...       ...       ...
# 45  0.176471  0.015075  0.245902 -0.030303 -0.574468 -0.019374 -0.920581
# 46 -0.764706  0.226131  0.147541 -0.454545  0.000000  0.096870 -0.776260
# 47 -0.411765  0.216080  0.180328 -0.535354 -0.735225 -0.219076 -0.857387
# 48 -0.882353  0.266332 -0.016393  0.000000  0.000000 -0.102832 -0.768574
# 49 -0.882353 -0.065327  0.147541 -0.373737  0.000000 -0.093890 -0.797609
#
#            7
# 0  -0.033333
# 1  -0.666667
# 2  -0.633333
# 3   0.000000
# 4  -0.600000
# ...

# %%
train.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  709.000000  709.000000  709.000000  709.000000  709.000000  709.000000
# mean    -0.402887    0.217576    0.173114   -0.291362   -0.324907   -0.034931
# std      0.384125    0.307420    0.201122    0.261057    0.376587    0.206563
# min     -0.882353   -0.557789   -0.606557   -0.858586   -0.966903   -0.457526
# 25%     -0.764706   -0.005025    0.016393   -0.494949   -0.716312   -0.183308
# 50%     -0.411765    0.165829    0.147541   -0.292929    0.000000   -0.037258
# 75%      0.000000    0.407035    0.311475    0.000000    0.000000    0.084948
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                 6           7
# count  709.000000  709.000000
# mean    -0.660509   -0.517913
# std      0.286892    0.401090
# min     -0.994876   -0.966667
# 25%     -0.861657   -0.866667
# 50%     -0.745517   -0.666667
# 75%     -0.522630   -0.233333
# ...

# %%
test.describe()
# Out:
#                0          1          2          3          4          5  \
# count  50.000000  50.000000  50.000000  50.000000  50.000000  50.000000
# mean   -0.475294   0.232563   0.224590  -0.266667  -0.304066   0.005842
# std     0.413534   0.294478   0.199442   0.219659   0.363544   0.185458
# min    -0.882353  -0.346734  -0.278689  -0.656566  -0.962175  -0.329359
# 25%    -0.882353   0.025126   0.090164  -0.454545  -0.692081  -0.126677
# 50%    -0.647059   0.190955   0.237705  -0.252525   0.000000  -0.023845
# 75%    -0.058824   0.399497   0.409836   0.000000   0.000000   0.112519
# max     0.529412   0.909548   0.540984   0.000000   0.205674   0.469449
#
#                6          7
# count  50.000000  50.000000
# mean   -0.702169  -0.491333
# std     0.220250   0.399762
# min    -0.946200  -0.966667
# 25%    -0.845004  -0.858333
# 50%    -0.768574  -0.533334
# 75%    -0.657344  -0.200000
# max    -0.057216   0.500000

# %%
hap.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  759.000000  759.000000  759.000000  759.000000  759.000000  759.000000
# mean    -0.407657    0.218563    0.176505   -0.289735   -0.323534   -0.032245
# std      0.386260    0.306419    0.201287    0.258480    0.375544    0.205376
# min     -0.882353   -0.557789   -0.606557   -0.858586   -0.966903   -0.457526
# 25%     -0.764706   -0.005025    0.016393   -0.494949   -0.716312   -0.178837
# 50%     -0.529412    0.165829    0.180328   -0.292929    0.000000   -0.034277
# 75%      0.000000    0.407035    0.311475    0.000000    0.000000    0.087928
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                 6           7
# count  759.000000  759.000000
# mean    -0.663253   -0.516162
# std      0.283056    0.400794
# min     -0.994876   -0.966667
# 25%     -0.858241   -0.866667
# 50%     -0.747225   -0.633333
# 75%     -0.531597   -0.233333
# ...

# %%
hap.columns
# Out:
# Index(['0', '1', '2', '3', '4', '5', '6', '7'], dtype='object')

# %%
sns.set()
cols = hap.columns
sns.pairplot(hap[cols], size = 2.5)
plt.show();

# %%
import seaborn as sns


# Load the example mpg dataset
mpg = sns.load_dataset("mpg")

# Plot miles per gallon against horsepower with other semantics
sns.relplot(x="horsepower", y="mpg", hue="origin", size="weight",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=mpg)

# %%
for i in hap.columns:
    print("##############"+i+"##############")
    print('max value of',i,':',hap[i].max())
    print('min value of',i,':',hap[i].min())
    print('mean value of',i,':',hap[i].mean())
# Out:
# ##############0##############
# max value of 0 : 1.0
# min value of 0 : -0.882353
# mean value of 0 : -0.40765724242424284
# ##############1##############
# max value of 1 : 1.0
# min value of 1 : -0.557789
# mean value of 1 : 0.21856314123847168
# ##############2##############
# max value of 2 : 1.0
# min value of 2 : -0.606557
# mean value of 2 : 0.17650491989459824
# ##############3##############
# max value of 3 : 1.0
# min value of 3 : -0.8585860000000001
# mean value of 3 : -0.2897352482213436
# ##############4##############
# max value of 4 : 1.0
# min value of 4 : -0.9669030000000001
# mean value of 4 : -0.3235344341238469
# ##############5##############
# max value of 5 : 1.0
# min value of 5 : -0.45752600000000004
# mean value of 5 : -0.03224491978919629
# ##############6##############
# max value of 6 : 1.0
# min value of 6 : -0.994876
# mean value of 6 : -0.6632530383662717
# ##############7##############
# max value of 7 : 1.0
# min value of 7 : -0.966667
# ...

# %%
type(hap.iloc[1,1])
# Out:
# numpy.float64

# %%
sns.lineplot(x='0', y= hap.iloc[:,1], data=hap)

# %%
x = hap.columns

# %%
x
# Out:
# Index(['0', '1', '2', '3', '4', '5', '6', '7'], dtype='object')

# %%
plt.figure(figsize=(10,10))
plt.plot(x, hap.iloc[:,'0'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     701             try:
# --> 702                 self._validate_key(k, i)
#     703             except ValueError:
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    2009         else:
# -> 2010             raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#    2011
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-444848db9481> in <module>
#       1 plt.figure(figsize=(10,10))
# ...

# %%
sns.factorplot(col=hap.columns,data=hap)
plt.show()

# %%
lst_0 = hap['0']

# %%
x = pd.DataFrame(lst_0)

# %%
pah = hap.T

# %%
pah
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.294118 -0.882353 -0.058824 -0.882353  0.000000 -0.411765 -0.647059
# 1  0.487437 -0.145729  0.839196 -0.105528  0.376884  0.165829 -0.216080
# 2  0.180328  0.081967  0.049180  0.081967 -0.344262  0.213115 -0.180328
# 3 -0.292929 -0.414141  0.000000 -0.535354 -0.292929  0.000000 -0.353535
# 4  0.000000  0.000000  0.000000 -0.777778 -0.602837  0.000000 -0.791962
# 5  0.001490 -0.207153 -0.305514 -0.162444  0.284650 -0.236960 -0.076006
# 6 -0.531170 -0.766866 -0.492741 -0.923997  0.887276 -0.894962 -0.854825
# 7 -0.033333 -0.666667 -0.633333  0.000000 -0.600000 -0.700000 -0.833333
#
#          7         8         9   ...        40        41        42        43  \
# 0  0.176471 -0.764706 -0.058824  ... -0.882353 -0.294118 -0.764706  0.058824
# 1  0.155779  0.979899  0.256281  ...  0.065327  0.909548 -0.115578  0.708543
# 2  0.000000  0.147541  0.573770  ...  0.245902  0.508197 -0.049180  0.213115
# ...

# %%
plt.plot(pah)

# %%
hap1 = hap.drop(hap[(hap['3'])>=1.0].index)

# %%
hap1t = hap1.T

# %%
plt.plot(hap1t)

# %%
train = train.drop(train[(train['GrLivArea']>4000) & (train['SalePrice']<300000)].index)

# %%
ttrain = train.T
plt.plot(ttrain)

# %%
train = train.drop(train[(train['3'])>=1.0].index)
train = train.drop(train[(train['4'])>=1.0].index)

# %%
ttrain = train.T
plt.plot(ttrain)
