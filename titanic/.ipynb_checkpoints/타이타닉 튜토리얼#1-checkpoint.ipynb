# %% [markdown]
# <a href='https://kaggle-kr.tistory.com/17?category=868316'>원본</a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')
sns.set(font_scale=2.5)

import missingno as msno
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# 앞으로 우리가 해야할 프로세스는 대략 아래와 같습니다.
# 1. 데이터셋 확인 - 대부분의 캐글 데이터들은 잘 정제되어 있습니다. 하지만 가끔 null data가 존재합니다. 이를 확인하고, 향후 수정합니다.
#
# 2. 탐색적 데이터 분석(exploratory data analysis) - 여러 feature 들을 개별적을 ㅗ분석하고, feature들 간의 상관관계를 확인합니다. 여러 시각화 툴을 사용하여 insight를 얻습니다.
#
# 3. feature engineering - 모델을 세우기에 앞서, 모델의 성능을 높일 수 있도록 feature들을 engineering합니다. one-hot encoding, class로 나누기, 구간으로 나누기, 텍스트 데이터 처리 등을 합니다.
#
# 4. model 만들기 - sklearn을 사용해 모델을 만듭니다. 파이썬에서 머신러닝을 할 때는 sklearn을 사용하면 수많은 알고리즘을 일관된 문법으로 사용할 수 있습니다. 물론 딥러닝을 위해 tensorflow나 pytorch등을 사용할 수도 있습니다.
#
# 5. 모델 학습 및 예측 - trainset을 가지고 모델을 학습시킨 후, testset을 가지고 prediction합니다.
#
# 6. 모델 평가 - 예측 성능이 원하는 수준인지 판단합니다. 풀려는 문제에 따라 모델을 평가하는 방식도 달라집니다. 학습된 모델이 어떤 것을 학습하였는지 확인합니다.

# %% [markdown]
# # 1. Dataset 확인

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Feature: Pclass, Age, SibSp, Parch, Fare
#
# Target Label: Survived

# %% [markdown]
# - describe는 feature가 가진 통계치들을 반환해준다

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# - 테이블에서 보다 시피 PassengerId 숫자와 다른, 그러니까 null data가 존재하는 열이 있는 것 같습니다.
# - 이를 좀 더 보기 편하도록 그래프로 시각화해서 살펴봅시다.

# %% [markdown]
# ## 1.1 Null data check

# %%
for col in df_train.columns:
    msg = 'column: {:>10}\t Percent of NaN value: {:.2f}%'.format(col, 100*(df_train[col].isnull().sum()/df_train[col].shape[0]))
    print(msg)
# Out:
# column: PassengerId	 Percent of NaN value: 0.00%
# column:   Survived	 Percent of NaN value: 0.00%
# column:     Pclass	 Percent of NaN value: 0.00%
# column:       Name	 Percent of NaN value: 0.00%
# column:        Sex	 Percent of NaN value: 0.00%
# column:        Age	 Percent of NaN value: 19.87%
# column:      SibSp	 Percent of NaN value: 0.00%
# column:      Parch	 Percent of NaN value: 0.00%
# column:     Ticket	 Percent of NaN value: 0.00%
# column:       Fare	 Percent of NaN value: 0.00%
# column:      Cabin	 Percent of NaN value: 77.10%
# column:   Embarked	 Percent of NaN value: 0.22%

# %%
for col in df_test.columns:
    msg = 'column: {:>10}\t Percent of NaN value: {:.2f}%'.format(col, 100*(df_train[col].isnull().sum()/df_train[col].shape[0]))
    print(msg)
# Out:
# column: PassengerId	 Percent of NaN value: 0.00%
# column:     Pclass	 Percent of NaN value: 0.00%
# column:       Name	 Percent of NaN value: 0.00%
# column:        Sex	 Percent of NaN value: 0.00%
# column:        Age	 Percent of NaN value: 19.87%
# column:      SibSp	 Percent of NaN value: 0.00%
# column:      Parch	 Percent of NaN value: 0.00%
# column:     Ticket	 Percent of NaN value: 0.00%
# column:       Fare	 Percent of NaN value: 0.00%
# column:      Cabin	 Percent of NaN value: 77.10%
# column:   Embarked	 Percent of NaN value: 0.22%

# %% [markdown]
# - Train, Test set에서 Age(둘 다 약 20%), Cabin(둘 다 약 80%), Embarked(train만 0.22%) null data가 존재하는 것을 볼 수 있습니다.
# - MSNO라는 라이브러리를 사용하면 null data의 존재를 더 쉽게 볼 수 있습니다.

# %%
msno.matrix(df=df_train.iloc[:,:],figsize=(8,8),color=(0.8,0.5,0.2))

# %%
msno.bar(df=df_train.iloc[:,:],figsize = (8,8), color=(0.8,0.5,0.2))

# %%
msno.bar(df=df_test.iloc[:, :],figsize=(8,8),color=(0.8,0.5,0.2))

# %% [markdown]
# ## 1.2 Target label 확인
# - target label이 어떤 distirbution을 가지고 있는지 확인해봐야 합니다.
# - 지금 같은 binary classification 문제의 경우에서, 1과 0의 분포가 어떠냐에 따라 모델의 평가 방법이 많이 달라질 수 있습니다

# %%
f, ax = plt.subplots(1,2,figsize=(18,8))
df_train['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Pie plot - Survived')
ax[0].set_ylabel('')

sns.countplot('Survived',data=df_train,ax=ax[1])
ax[1].set_title('Count plot - Survived')

plt.show()

# %% [markdown]
# ## EDA
# - 시각화 라이브러리는 matplotlib, seaborn, plotly 등이 있습니다. 특정 목적에 맞는 소스코드를 정리해두어 필요할 때마다 참고하면 편합니다.

# %% [markdown]
# ### 2.1 Pclass
# - pclass는  ordinal, 서수형 데이터/ 카테고리 + 순서
# - groupby로 묶어서 확인

# %%
df_train[['Pclass','Survived']].groupby(['Pclass'],as_index=True).count()
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %%
df_train[['Pclass','Survived']]
# Out:
#      Pclass  Survived
# 0         3         0
# 1         1         1
# 2         3         1
# 3         1         1
# 4         3         0
# ..      ...       ...
# 886       2         0
# 887       1         1
# 888       3         0
# 889       1         1
# 890       3         0
#
# [891 rows x 2 columns]

# %%
df_train[['Pclass','Survived']].groupby(['Pclass'],as_index=True).sum()
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %%
pd.crosstab(df_train['Pclass'],df_train['Survived'],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_c079d088_095b_11eb_b69a_00d8619dd5d4row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c079d088_095b_11eb_b69a_00d8619dd5d4row0_col1 {
#             background-color:  #cee666;
#             color:  #000000;
#         }    #T_c079d088_095b_11eb_b69a_00d8619dd5d4row0_col2 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_c079d088_095b_11eb_b69a_00d8619dd5d4row1_col0 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_c079d088_095b_11eb_b69a_00d8619dd5d4row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c079d088_095b_11eb_b69a_00d8619dd5d4row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c079d088_095b_11eb_b69a_00d8619dd5d4row2_col0 {
#             background-color:  #60b066;
#             color:  #000000;
# ...

# %% [markdown]
# - grouped 객체에 mean을 하게 되면 각 클래스별 생존률을 얻을 수 있습니다.

# %%
df_train[['Pclass','Survived']].groupby(['Pclass'],as_index=True).mean().sort_values(by='Survived',ascending=True).plot.bar()

# %%
y_position=1.02
f,ax = plt.subplots(1,2,figsize=(18,8))
df_train['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number of Passengers by Pclass')
ax[0].set_ylabel('Count')

sns.countplot('Pclass', hue='Survived',data=df_train,ax=ax[1])
ax[1].set_title('Pclass: Survived vs Dead', y=y_position)
plt.show()

# %% [markdown]
# - Pclass가 높을수록 생존 확률이 높군요
# - Pclass가 큰 영향을 미칠 것입니다.

# %% [markdown]
# ### 2.2 Sex
# - 성별에 따라도 달라지는지 확인

# %%
f, ax = plt.subplots(1,2,figsize=(18,8))
df_train[['Sex','Survived']].groupby(['Sex'],as_index=False).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data=df_train,ax=ax[1])
ax[1].set_title('Sex: Survived vs Dead')
plt.show()

# %%
df_train[['Sex','Survived']].groupby(['Sex'],as_index=True).mean().sort_values(by='Survived',ascending=False)
pd.crosstab(df_train['Sex'],df_train['Survived'],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_7465566c_095c_11eb_86dd_00d8619dd5d4row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_7465566c_095c_11eb_86dd_00d8619dd5d4row0_col1 {
#             background-color:  #77bb66;
#             color:  #000000;
#         }    #T_7465566c_095c_11eb_86dd_00d8619dd5d4row0_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_7465566c_095c_11eb_86dd_00d8619dd5d4row1_col0 {
#             background-color:  #2c9666;
#             color:  #000000;
#         }    #T_7465566c_095c_11eb_86dd_00d8619dd5d4row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_7465566c_095c_11eb_86dd_00d8619dd5d4row1_col2 {
#             background-color:  #8bc566;
#             color:  #000000;
#         }    #T_7465566c_095c_11eb_86dd_00d8619dd5d4row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
# ...

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=df_train,size=6,aspect=1.5)
