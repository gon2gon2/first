# %% [markdown]
# <a href="https://www.kaggle.com/ash316/eda-to-prediction-dietanic">원본</a>

# %% [markdown]
# ## Contents of the Notebook:
#
# ### Part1: Exploratory Data Analysis
# 1) Analysis of the features.
#
# 2) Finding any relations or trends considering multiple features.
#
# ### Part2: Feature Engineering and Data Cleaning
# 1) Adding any few features.
#
# 2) Removing redundant features.
#
# 3) Converting features into suitable from for modeling.
#
# ### Part3: Predictive Modeling
# 1) Running Basic Algorithms.
#
# 2) Cross Valdation
#
# 3) Ensembling
#
# 4) Important Features Extraction

# %% [markdown]
# # Part1: Exploratory Data Analysis(EDA)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('train.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# The **Age, Cabin and Embarked** haver null values. I will try to fit them.

# %% [markdown]
# ### How many survived?

# %%
f,ax = plt.subplots(1,2,figsize=(18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data, ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# It is evident that not many passengers survived the accident.
# Out of 891 passengers in training set, only around 350 survived i.e Only **38.4%** of the total training set survived the crash. We need to dig down more to get better insights from the data and see which categories of the passengers did survived and who didn't.
#
# We will try to check the survival rate by using the different features of the dataset. Some of the features being Sex, Port of Embarcation, Age, ect.
#
# First let us understand the different types of features.

# %% [markdown]
# ## Types of features
#
# ### Categorical Features
# A categorical variable is one that has two or more categories and each values in that feature can be cateogrized by them. For example, gender is a categorical variable having two categories (male and female). Now we cannot sort or give any odering to such variables. They are also known as Nominal Variables.
#
# Categorical faetures in the dataset: Sex, Embarked
#
# ### Ordinal Features
# An ordinal variable is similar to categorical values, but the difference between them is that we can have relative ordering or sorting between the values. For eg: If we have a feature like Height with value Tall, Medium, Short, then Height is a ordinal variable. Here we can have a relative sort in the variable.
#
# Ordinal Features in the dataset: PClass
#
# ### Continuos Feature:
# A feature is said to be continuos if it can take values between any two points or between the minimum or maximum values in the features column.
#
# Continuos Features in the dataset: Age

# %% [markdown]
# ## Analysing the features
#
# ## Sex -> Categorical Feature

# %%
pd.crosstab(data.Sex,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_66608cf0_0b6c_11eb_8762_00d8619dd5d4row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_66608cf0_0b6c_11eb_8762_00d8619dd5d4row0_col1 {
#             background-color:  #77bb66;
#             color:  #000000;
#         }    #T_66608cf0_0b6c_11eb_8762_00d8619dd5d4row0_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_66608cf0_0b6c_11eb_8762_00d8619dd5d4row1_col0 {
#             background-color:  #2c9666;
#             color:  #000000;
#         }    #T_66608cf0_0b6c_11eb_8762_00d8619dd5d4row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_66608cf0_0b6c_11eb_8762_00d8619dd5d4row1_col2 {
#             background-color:  #8bc566;
#             color:  #000000;
#         }    #T_66608cf0_0b6c_11eb_8762_00d8619dd5d4row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_66608cf0_0b6c_11eb_8762_00d8619dd5d4row2_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_66608cf0_0b6c_11eb_8762_00d8619dd5d4row2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_66608cf0_0b6c_11eb_8762_00d8619dd5d4" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_66608cf0_0b6c_11eb_8762_00d8619dd5d4level0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_66608cf0_0b6c_11eb_8762_00d8619dd5d4row0_col0" class="data row0 col0" >81</td>
#                         <td id="T_66608cf0_0b6c_11eb_8762_00d8619dd5d4row0_col1" class="data row0 col1" >233</td>
#                         <td id="T_66608cf0_0b6c_11eb_8762_00d8619dd5d4row0_col2" class="data row0 col2" >314</td>
#             </tr>
#             <tr>
#                         <th id="T_66608cf0_0b6c_11eb_8762_00d8619dd5d4level0_row1" class="row_heading level0 row1" >male</th>
#                         <td id="T_66608cf0_0b6c_11eb_8762_00d8619dd5d4row1_col0" class="data row1 col0" >468</td>
#                         <td id="T_66608cf0_0b6c_11eb_8762_00d8619dd5d4row1_col1" class="data row1 col1" >109</td>
#                         <td id="T_66608cf0_0b6c_11eb_8762_00d8619dd5d4row1_col2" class="data row1 col2" >577</td>
#             </tr>
#             <tr>
#                         <th id="T_66608cf0_0b6c_11eb_8762_00d8619dd5d4level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_66608cf0_0b6c_11eb_8762_00d8619dd5d4row2_col0" class="data row2 col0" >549</td>
#                         <td id="T_66608cf0_0b6c_11eb_8762_00d8619dd5d4row2_col1" class="data row2 col1" >342</td>
#                         <td id="T_66608cf0_0b6c_11eb_8762_00d8619dd5d4row2_col2" class="data row2 col2" >891</td>
#             </tr>
#     </tbody></table>

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f, ax = plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex: Survived vs Dead')
plt.show()

# %% [markdown]
# This looks intersting. The number of men on the ship is lot more than the number of women. Still the number of women saved is almost twice the number of males saved. The survival rates for a women on the ship is aroun 75% while that for men in around 18-19%.
#
# This looks to be a very important feature for modeling. But is it the best?? Lets check other features.

# %% [markdown]
# ##  Pclass -> Ordinal Feature

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row0_col1 {
#             background-color:  #cee666;
#             color:  #000000;
#         }    #T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row0_col2 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row1_col0 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row2_col0 {
#             background-color:  #60b066;
#             color:  #000000;
#         }    #T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row2_col1 {
#             background-color:  #dfef66;
#             color:  #000000;
#         }    #T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row2_col2 {
#             background-color:  #90c866;
#             color:  #000000;
#         }    #T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row3_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row3_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row3_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row0_col1" class="data row0 col1" >136</td>
#                         <td id="T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row2_col0" class="data row2 col0" >372</td>
#                         <td id="T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row2_col1" class="data row2 col1" >119</td>
#                         <td id="T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row3_col0" class="data row3 col0" >549</td>
#                         <td id="T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row3_col1" class="data row3 col1" >342</td>
#                         <td id="T_6685f7f4_0b6c_11eb_b419_00d8619dd5d4row3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %%
f,ax = plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number of Passengers by Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title("Pclass: Survived vs Dead")
plt.show()

# %% [markdown]
# People say Money can'y buy everything. But we can clearly see that Passengers of pclass 1 were give a very high priority while rescue. Evne though the number of Passengers in Pclass 3 were a lot higher, still the number of survival from them is very low, somewhere around25%.
#
# For plcaas 1% survived is around 63 % while for pclass2 is around 48%. So money and status matters. Such a materialistic world.
#
# Lets dive in little bit more and check for other interesting observations. Lets check survival rate with Sex and Pclass together.

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row0_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row1_col0 {
#             background-color:  #96cb66;
#             color:  #000000;
#         }    #T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row1_col1 {
#             background-color:  #a3d166;
#             color:  #000000;
#         }    #T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row1_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row1_col3 {
#             background-color:  #cfe766;
#             color:  #000000;
#         }    #T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row2_col0 {
#             background-color:  #a7d366;
#             color:  #000000;
#         }    #T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row2_col1 {
#             background-color:  #85c266;
#             color:  #000000;
#         }    #T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row2_col2 {
#             background-color:  #6eb666;
#             color:  #000000;
#         }    #T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row2_col3 {
#             background-color:  #85c266;
#             color:  #000000;
#         }    #T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row3_col0 {
#             background-color:  #cde666;
#             color:  #000000;
#         }    #T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row3_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row3_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row3_col3 {
#             background-color:  #f7fb66;
#             color:  #000000;
#         }    #T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row4_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row4_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row4_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row4_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4level0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#                         <th id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4level1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row0_col0" class="data row0 col0" >3</td>
#                         <td id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row0_col1" class="data row0 col1" >6</td>
#                         <td id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row0_col2" class="data row0 col2" >72</td>
#                         <td id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4level1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row1_col0" class="data row1 col0" >91</td>
#                         <td id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row1_col1" class="data row1 col1" >70</td>
#                         <td id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row1_col2" class="data row1 col2" >72</td>
#                         <td id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row1_col3" class="data row1 col3" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4level0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#                         <th id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4level1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row2_col0" class="data row2 col0" >77</td>
#                         <td id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row2_col1" class="data row2 col1" >91</td>
#                         <td id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row2_col2" class="data row2 col2" >300</td>
#                         <td id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row2_col3" class="data row2 col3" >468</td>
#             </tr>
#             <tr>
#                                 <th id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4level1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row3_col0" class="data row3 col0" >45</td>
#                         <td id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row3_col1" class="data row3 col1" >17</td>
#                         <td id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row3_col2" class="data row3 col2" >47</td>
#                         <td id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row3_col3" class="data row3 col3" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4level0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4level1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row4_col0" class="data row4 col0" >216</td>
#                         <td id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row4_col1" class="data row4 col1" >184</td>
#                         <td id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row4_col2" class="data row4 col2" >491</td>
#                         <td id="T_66adfb9e_0b6c_11eb_aaf6_00d8619dd5d4row4_col3" class="data row4 col3" >891</td>
#             </tr>
#     </tbody></table>

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=data)
plt.show()

# %% [markdown]
# We use factorplot in this case, because they make the seperation of categorical values easy. Looking at the crosstab and the factorplot, we can easily infer that survival for women from plcass1 is about 95%-96%, as only 3 out of 94 Women from Pclass1 died.
#
# it its evident that irrespective of Pclass, Women were giver first priority while rescue. Even Men from Pclass1 have a very low survival rate.
#
# Looks like Pclass is also an important feature. Lets analyse other features.

# %% [markdown]
# ## Age -> Continuos Feature

# %%
print("Oldest Passenger was of:",data['Age'].max(),'Years')
print("Youngest Passenger was of:",data['Age'].min(),'Years')
print("Average Passenger was of:",data["Age"].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Passenger was of: 29.69911764705882 Years

# %%
f,ax = plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age",hue='Survived',data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex",'Age',hue='Survived',data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %% [markdown]
# **Observations:**
# 1) The number of children increases with Pclass and the survival rate for passengers below Age 10 looks to be good irrespective of the Pclass.
#
# 2) Survival chances for passengers aged 20-50 from Pclass 1 is high and is even better for Women.
#
# 3) For males, the survival chances decreases with an increase in Age.

# %% [markdown]
# As we had seen earlier, the Age feature has 177 null values. To replace these NaN values, we can assign them the mean age of the dataset.
#
# But the problem is, there were many people with many different ages. We just assign a 4 year kid with the mean age that is 29 years. Is there any way to fond out what age-band does the passengers lie??
#
# Bingo!!, we can check the Naem feature. Looking upon the feature, we can see that thte names have a salutation like Mr or Mrs. Thus we can assign the mean values of Mr and Mrs to the repective groups.
#
# What's in a Name? --> Feature :p

# %%
data['Inintial'] = 0
for i in data:
    data["Initial"]=data.Name.str.extract('([A-Za-z]+\.)')

# %% [markdown]
# Okay, so here we are using the Regex: [A-Za-z]+)..So what it does is, it looks for strings which lie between A-Z or a-z and followed by a .(dot). So we successfully extract the Initials from the Name.

# %%
pd.crosstab(data.Initial,data.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col9 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col10 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col11 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col12 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col13 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col14 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col15 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col16 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row1_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row1_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row1_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row1_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row1_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row1_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row1_col7 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row1_col8 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row1_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row1_col10 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row1_col11 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row1_col12 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row1_col13 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row1_col14 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row1_col15 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row1_col16 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_67099e6c_0b6c_11eb_8717_00d8619dd5d4" ><thead>    <tr>        <th class="index_name level0" >Initial</th>        <th class="col_heading level0 col0" >Capt.</th>        <th class="col_heading level0 col1" >Col.</th>        <th class="col_heading level0 col2" >Countess.</th>        <th class="col_heading level0 col3" >Don.</th>        <th class="col_heading level0 col4" >Dr.</th>        <th class="col_heading level0 col5" >Jonkheer.</th>        <th class="col_heading level0 col6" >Lady.</th>        <th class="col_heading level0 col7" >Major.</th>        <th class="col_heading level0 col8" >Master.</th>        <th class="col_heading level0 col9" >Miss.</th>        <th class="col_heading level0 col10" >Mlle.</th>        <th class="col_heading level0 col11" >Mme.</th>        <th class="col_heading level0 col12" >Mr.</th>        <th class="col_heading level0 col13" >Mrs.</th>        <th class="col_heading level0 col14" >Ms.</th>        <th class="col_heading level0 col15" >Rev.</th>        <th class="col_heading level0 col16" >Sir.</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_67099e6c_0b6c_11eb_8717_00d8619dd5d4level0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col2" class="data row0 col2" >1</td>
#                         <td id="T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col4" class="data row0 col4" >1</td>
#                         <td id="T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col6" class="data row0 col6" >1</td>
#                         <td id="T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col9" class="data row0 col9" >182</td>
#                         <td id="T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col10" class="data row0 col10" >2</td>
#                         <td id="T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col11" class="data row0 col11" >1</td>
#                         <td id="T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col12" class="data row0 col12" >0</td>
#                         <td id="T_67099e6c_0b6c_11eb_8717_00d8619dd5d4row0_col13" class="data row0 col13" >125</td>

# %% [markdown]
# Okay so there are some misspelled Initials like Mlle or Mme that stand for Miss. I will replace them with Miss and same thing for other values.

# %%
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
data['Initial'].unique()
# Out:
# array(['Mr.', 'Mrs.', 'Miss.', 'Master.', 'Don.', 'Rev.', 'Dr.', 'Mme.',
#        'Ms.', 'Major.', 'Lady.', 'Sir.', 'Mlle.', 'Col.', 'Capt.',
#        'Countess.', 'Jonkheer.'], dtype=object)

# %% [markdown]
# # whyrano????

# %%
data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Capt.        70.000000
# Col.         58.000000
# Countess.    33.000000
# Don.         40.000000
# Dr.          42.000000
# Jonkheer.    38.000000
# Lady.        48.000000
# Major.       48.500000
# Master.       4.574167
# Miss.        21.773973
# Mlle.        24.000000
# Mme.         24.000000
# Mr.          32.368090
# Mrs.         35.898148
# Ms.          28.000000
# Rev.         43.166667
# Sir.         49.000000
# Name: Age, dtype: float64
